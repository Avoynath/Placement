# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv('/content/placement.csv')

# %%
df.head()
# Out:
#    Unnamed: 0  cgpa     iq  placement
# 0           0   6.8  123.0          1
# 1           1   5.9  106.0          0
# 2           2   5.3  121.0          0
# 3           3   7.4  132.0          1
# 4           4   5.8  142.0          0

# %%
df.shape
# Out:
# (100, 4)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 4 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  100 non-null    int64
#  1   cgpa        100 non-null    float64
#  2   iq          100 non-null    float64
#  3   placement   100 non-null    int64
# dtypes: float64(2), int64(2)
# memory usage: 3.2 KB

# %%
df = df.iloc[:,1:]

# %%
df.head()
# Out:
#    cgpa     iq  placement
# 0   6.8  123.0          1
# 1   5.9  106.0          0
# 2   5.3  121.0          0
# 3   7.4  132.0          1
# 4   5.8  142.0          0

# %%
import matplotlib.pyplot as plt

# %%
plt.scatter(df['cgpa'],df['iq'], c=df['placement'])

# %%
x=df.iloc[:,0:2]
y=df.iloc[:,-1]

# %%
x
# Out:
#     cgpa     iq
# 0    6.8  123.0
# 1    5.9  106.0
# 2    5.3  121.0
# 3    7.4  132.0
# 4    5.8  142.0
# ..   ...    ...
# 95   4.3  200.0
# 96   4.4   42.0
# 97   6.7  182.0
# 98   6.3  103.0
# 99   6.2  113.0
#
# [100 rows x 2 columns]

# %%
y
# Out:
# 0     1
# 1     0
# 2     0
# 3     1
# 4     0
#      ..
# 95    0
# 96    0
# 97    1
# 98    1
# 99    1
# Name: placement, Length: 100, dtype: int64

# %%
y.shape
# Out:
# (100,)

# %%
from sklearn.model_selection import train_test_split

x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=0.1)

# %%
x_train
# Out:
#     cgpa     iq
# 64   7.0   64.0
# 44   7.5   61.0
# 27   6.0  124.0
# 94   4.7   52.0
# 42   7.6   89.0
# ..   ...    ...
# 61   7.3  137.0
# 47   5.2  161.0
# 58   8.0   79.0
# 10   6.0   45.0
# 83   7.5  130.0
#
# [90 rows x 2 columns]

# %%
y_train
# Out:
# 64    1
# 44    1
# 27    1
# 94    0
# 42    1
#      ..
# 61    1
# 47    0
# 58    1
# 10    1
# 83    1
# Name: placement, Length: 90, dtype: int64

# %%
x_test
# Out:
#     cgpa     iq
# 8    6.1  156.0
# 0    6.8  123.0
# 72   7.3  116.0
# 3    7.4  132.0
# 79   6.5   90.0
# 85   5.8  166.0
# 96   4.4   42.0
# 77   7.3   50.0
# 28   5.2   90.0
# 50   3.5  233.0

# %%
y_test
# Out:
# 8     0
# 0     1
# 72    1
# 3     1
# 79    1
# 85    1
# 96    0
# 77    1
# 28    0
# 50    0
# Name: placement, dtype: int64

# %%
from sklearn.preprocessing import StandardScaler

# %%
scaler = StandardScaler()

# %%
x_train=scaler.fit_transform(x_train)

# %%
x_train
# Out:
# array([[ 0.90138294, -1.58686728],
#        [ 1.34614426, -1.66621064],
#        [ 0.0118603 ,  0.        ],
#        [-1.14451913, -1.90424074],
#        [ 1.43509653, -0.92567258],
#        [ 0.72347841,  0.4496124 ],
#        [ 1.87985785,  1.1108071 ],
#        [ 1.61300105, -0.26447788],
#        [-0.87766234, -1.61331507],
#        [ 0.10081257, -0.55540355],
#        [-1.76718498, -0.63474691],
#        [ 0.81243068, -0.74053806],
#        [ 0.54557389,  0.37026903],
#        [-1.14451913, -0.97856816],
#        [-0.52185328,  0.29092567],
#        [ 0.18976483, -0.29092567],
#        [-0.78871007,  0.10579115],
#        [ 2.2356669 , -0.10579115],
#        [-0.25499649,  0.42316461],
#        [ 0.0118603 , -1.5339717 ],
#        [-0.25499649,  1.19015046],
#        [-1.41137592,  0.6611947 ],
#        [ 0.63452615,  1.5339717 ],
#        [-0.9666146 ,  1.90424074],
#        [-0.61080555, -0.26447788],
#        [-0.9666146 ,  0.81988143],
#        [-0.69975781, -0.37026903],
#        [ 0.81243068,  0.39671682],
#        [ 0.36766936, -0.2115823 ],
#        [-1.14451913, -0.07934336],
#        [ 0.81243068,  0.37026903],
#        [-0.52185328, -0.26447788],
#        [-0.9666146 , -0.10579115],
#        [-0.52185328, -0.4496124 ],
#        [ 0.99033521, -2.01003189],
#        [ 0.0118603 , -0.58185134],
#        [-0.16604423,  0.47606018],
#        [ 0.27871709,  0.07934336],
#        [-0.25499649,  0.2115823 ],
#        [ 0.54557389, -0.10579115],
#        [-0.52185328,  0.39671682],
#        [-0.9666146 ,  0.26447788],
#        [-1.50032819,  2.01003189],
#        [ 0.45662162, -2.30095756],
#        [-1.85613724, -0.39671682],
#        [ 0.90138294,  1.34883719],
#        [ 0.45662162,  0.95212037],
#        [ 0.27871709, -0.55540355],
#        [ 0.27871709,  0.10579115],
#        [-0.9666146 ,  0.71409028],
#        [ 0.99033521,  0.71409028],
#        [ 1.87985785,  0.6611947 ],
#        [ 0.10081257, -1.13725488],
#        [ 0.0118603 ,  0.6611947 ],
#        [-1.05556687,  1.19015046],
#        [-1.05556687,  1.03146373],
#        [ 1.16823973, -1.00501594],
#        [-0.87766234, -0.872777  ],
#        [ 0.10081257, -1.56041949],
#        [-0.69975781,  0.2115823 ],
#        [-2.38985083,  1.56041949],
#        [ 0.72347841, -0.89922479],
#        [-0.69975781,  2.6447788 ],
#        [-0.07709196, -0.47606018],
#        [ 0.45662162,  0.15868673],
#        [ 1.43509653,  0.10579115],
#        [-0.78871007, -1.5339717 ],
#        [ 0.90138294,  0.39671682],
#        [-0.25499649,  0.50250797],
#        [-0.87766234, -0.15868673],
#        [ 0.72347841, -0.31737346],
#        [-1.76718498, -1.29594161],
#        [-0.61080555, -0.07934336],
#        [-1.05556687, -0.31737346],
#        [ 1.34614426,  0.89922479],
#        [-1.05556687,  0.4496124 ],
#        [ 0.90138294,  1.9835841 ],
#        [-0.78871007,  1.37528498],
#        [ 0.10081257,  0.2115823 ],
#        [ 2.05776237,  1.16370267],
#        [-1.23347139,  0.58185134],
#        [-0.9666146 , -1.66621064],
#        [ 0.90138294, -0.31737346],
#        [ 0.63452615,  0.79343364],
#        [ 0.36766936,  0.4496124 ],
#        [ 1.16823973,  0.34382124],
#        [-0.69975781,  0.97856816],
#        [ 1.79090558, -1.19015046],
#        [ 0.0118603 , -2.08937525],
#        [ 1.34614426,  0.15868673]])

# %%
x_test = scaler.transform(x_test)

# %%
x_test
# Out:
# array([[ 0.10081257,  0.84632922],
#        [ 0.72347841, -0.02644779],
#        [ 1.16823973, -0.2115823 ],
#        [ 1.257192  ,  0.2115823 ],
#        [ 0.45662162, -0.89922479],
#        [-0.16604423,  1.1108071 ],
#        [-1.41137592, -2.16871862],
#        [ 1.16823973, -1.95713631],
#        [-0.69975781, -0.89922479],
#        [-2.2119463 ,  2.88280889]])

# %%
from sklearn.linear_model import LogisticRegression

# %%
clf=LogisticRegression()

# %%
#model training
clf.fit(x_train,y_train)
# Out:
# LogisticRegression()

# %%
y_pred = clf.predict(x_test)

# %%
y_test
# Out:
# 8     0
# 0     1
# 72    1
# 3     1
# 79    1
# 85    1
# 96    0
# 77    1
# 28    0
# 50    0
# Name: placement, dtype: int64

# %%
from sklearn.metrics import accuracy_score

# %%
accuracy_score(y_test,y_pred)
# Out:
# 0.8

# %%
from mlxtend.plotting import plot_decision_regions

# %%
plot_decision_regions(x_train, y_train.values, clf=clf, legend=2)
# Out:
# <Axes: >

# %%
import pickle

# %%
pickle.dump(clf,open('model.pkl','wb'))
